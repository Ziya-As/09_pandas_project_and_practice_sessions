# %%
import pandas as pd

# %%
df = pd.read_csv("./files/CricketTestMatchData.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 63   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 64  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 65  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 66    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 67   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50     0    4s   6s
# 0   58.60   29  13   7.0  626+    6
# ...

# %%
df = df.rename(columns= {
  "Mat": "Matches",
  "NO": "Not_Outs", 
  "HS": "Highest_Inns_Score",
  "BF": "Balls_Faced",
  "SR": "Batting_Strike_Rate"
})

# %%
df.head().T
# Out:
#                                     0                 1               2  \
# Player               DG Bradman (AUS)  PHKD Mendis (SL)  AC Voges (AUS)
# Span                        1928-1948         2022-2025       2015-2016
# Matches                            52                14              20
# Inns                               80                24              31
# Not_Outs                           10                 3               7
# Runs                             6996              1316            1485
# Highest_Inns_Score                334              182*            269*
# Ave                             99.94             62.66           61.87
# Balls_Faced                     9800+              2063            2667
# Batting_Strike_Rate              58.6             63.79           55.68
# 100                                29                 5               5
# 50                                 13                 5               4
# ...

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                       True
# 4s                      True
# 6s                      True
# dtype: bool

# %%
df[df["Balls_Faced"].isna()]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9         ED Weekes (WI)  1948-1958       48    81         5  4455
# 17       CL Walcott (WI)  1948-1960       44    74         7  3798
# 60  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 9                 207  58.61         NaN                  NaN   15  19  6.0
# 17                220  56.68         NaN                  NaN   15  14  1.0
# 60               144*  48.79         NaN                  NaN    5   6  3.0
#
#       4s  6s
# 9   258+   2
# 17  107+  11
# 60   51+   0

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df[df["Balls_Faced"].isna()]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df["Batting_Strike_Rate"] = df["Batting_Strike_Rate"].fillna(0)

# %%
df[df["Player"] == "ED Weekes (WI)"]
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 9                207  58.61           0                  0.0   15  19  6.0
#
#      4s 6s
# 9  258+  2

# %%
df[df["Player"] == "CL Walcott (WI)"]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 17  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 17                220  56.68           0                  0.0   15  14  1.0
#
#       4s  6s
# 17  107+  11

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# Length: 68, dtype: bool

# %%
df[df["Player"].duplicated()]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 5   GA Headley (WI)  1930-1954       22    40         4  2190
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 59    V Kohli (IND)  2011-2023      109   185        11  8479
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 5                270*  60.83        416+                56.00   10   5   2.0
# 12               365*  57.78       4063+                53.58   26  30  12.0
# 16                211  56.94       5363+                46.22   15  28   4.0
# 59               254*  48.72       15320                55.34   28  28  14.0
#
#       4s   6s
# 5   104+    1
# 12  593+  32+
# 16  276+    8
# 59   950   24

# %%
list(df[df["Player"].duplicated()]["Player"])
# Out:
# ['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)']

# %%
df[df["Player"].isin(list(df[df["Player"].duplicated()]["Player"]))]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 5   GA Headley (WI)  1930-1954       22    40         4  2190
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 58    V Kohli (IND)  2011-2023      109   185        11  8479
# 59    V Kohli (IND)  2011-2023      109   185        11  8479
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 4                270*  60.83        416+                56.00   10   5   2.0
# 5                270*  60.83        416+                56.00   10   5   2.0
# 11               365*  57.78       4063+                53.58   26  30  12.0
# 12               365*  57.78       4063+                53.58   26  30  12.0
# ...

# %%
df = df.drop_duplicates()

# %%
df[df["Player"].isin(['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 58    V Kohli (IND)  2011-2023      109   185        11  8479
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 4                270*  60.83        416+                56.00   10   5   2.0
# 11               365*  57.78       4063+                53.58   26  30  12.0
# 15                211  56.94       5363+                46.22   15  28   4.0
# 58               254*  48.72       15320                55.34   28  28  14.0
#
#       4s   6s
# 4   104+    1
# 11  593+  32+
# 15  276+    8
# 58   950   24

# %%
df["Rookie_Year"] = df["Span"].str.split(pat = "-").str[0]

# %%
# df["Rookie_Year"] = list(df["Span"].str.split("-").explode())[::2]

# %%
df["Final_Year"] = df["Span"].str.split(pat = "-").str[1]

# %%
df.head(1)
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 0                334  99.94       9800+                 58.6   29  13  7.0
#
#      4s 6s Rookie_Year Final_Year
# 0  626+  6        1928       1948

# %%
df = df.drop(["Span"], axis=1)

# %%
df.head(5)
# Out:
#              Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1  PHKD Mendis (SL)       14    24         3  1316               182*  62.66
# 2    AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)       23    41         4  2256                274  60.97
# 4   GA Headley (WI)       22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7.0  626+   6        1928
# 1        2063                63.79    5   5  NaN   137  24        2022
# 2        2667                55.68    5   4  2.0   186   5        2015
# 3       1707+                54.48    7  11  1.0  246+  11        1963
# 4        416+                56.00   10   5  2.0  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2025
# 2       2016
# 3       1970
# ...

# %%
df["Player"].str.split(pat="(").str[1]
# Out:
# 0        AUS)
# 1         SL)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 63       AUS)
# 64    ICC/SA)
# 65       AUS)
# 66       AUS)
# 67       ENG)
# Name: Player, Length: 64, dtype: object

# %%
df["Country"] = df["Player"].str.split(pat="(").str[1]

# %%
df["Country"].str.split(pat=")").str[0]
# Out:
# 0        AUS
# 1         SL
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 63       AUS
# 64    ICC/SA
# 65       AUS
# 66       AUS
# 67       ENG
# Name: Country, Length: 64, dtype: object

# %%
df["Country"] = df["Country"].str.split(pat=")").str[0]

# %%
df["Country"]
# Out:
# 0        AUS
# 1         SL
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 63       AUS
# 64    ICC/SA
# 65       AUS
# 66       AUS
# 67       ENG
# Name: Country, Length: 64, dtype: object

# %%
df["Player"].str.split(pat="(").str[0]
# Out:
# 0      DG Bradman
# 1     PHKD Mendis
# 2        AC Voges
# 3      RG Pollock
# 4      GA Headley
#           ...
# 63     KD Walters
# 64       GC Smith
# 65    WH Ponsford
# 66      SJ McCabe
# 67     DR Jardine
# Name: Player, Length: 64, dtype: object

# %%
df["Player"] = df["Player"].str.split(pat="(").str[0]

# %%
df["Player"]
# Out:
# 0      DG Bradman
# 1     PHKD Mendis
# 2        AC Voges
# 3      RG Pollock
# 4      GA Headley
#           ...
# 63     KD Walters
# 64       GC Smith
# 65    WH Ponsford
# 66      SJ McCabe
# 67     DR Jardine
# Name: Player, Length: 64, dtype: object

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                334  99.94
# 1  PHKD Mendis        14    24         3  1316               182*  62.66
# 2     AC Voges        20    31         7  1485               269*  61.87
# 3   RG Pollock        23    41         4  2256                274  60.97
# 4   GA Headley        22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7.0  626+   6        1928
# 1        2063                63.79    5   5  NaN   137  24        2022
# 2        2667                55.68    5   4  2.0   186   5        2015
# 3       1707+                54.48    7  11  1.0  246+  11        1963
# 4        416+                56.00   10   5  2.0  104+   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2025      SL
# 2       2016     AUS
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df["Highest_Inns_Score"].str.split(pat="*").str[0]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 64, dtype: object

# %%
df["Highest_Inns_Score"] = df["Highest_Inns_Score"].str.split(pat="*").str[0]

# %%
df["Highest_Inns_Score"]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 64, dtype: object

# %%
df["Highest_Inns_Score"] = df["Highest_Inns_Score"].astype("int")

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df = df.astype({"Rookie_Year":"int", "Final_Year": "int"})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                 334  99.94
# 1  PHKD Mendis        14    24         3  1316                 182  62.66
# 2     AC Voges        20    31         7  1485                 269  61.87
# 3   RG Pollock        23    41         4  2256                 274  60.97
# 4   GA Headley        22    40         4  2190                 270  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s  Rookie_Year  \
# 0       9800+                58.60   29  13  7.0  626+   6         1928
# 1        2063                63.79    5   5  NaN   137  24         2022
# 2        2667                55.68    5   4  2.0   186   5         2015
# 3       1707+                54.48    7  11  1.0  246+  11         1963
# 4        416+                56.00   10   5  2.0  104+   1         1930
#
#    Final_Year Country
# 0        1948     AUS
# 1        2025      SL
# ...

# %%
df["Balls_Faced"] = df["Balls_Faced"].str.split(pat="+").str[0]

# %%
df.loc[[9, 17, 60], "Balls_Faced"] = 0

# %%
df[df["Balls_Faced"].isna()]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
df["Balls_Faced"].astype("int")
# Out:
# 0      9800
# 1      2063
# 2      2667
# 3      1707
# 4       416
#       ...
# 63     8662
# 64    15525
# 65     3118
# 66     3217
# 67     2110
# Name: Balls_Faced, Length: 64, dtype: int64

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df["career_length"] = df["Final_Year"] - df["Rookie_Year"]

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                 334  99.94
# 1  PHKD Mendis        14    24         3  1316                 182  62.66
# 2     AC Voges        20    31         7  1485                 269  61.87
# 3   RG Pollock        23    41         4  2256                 274  60.97
# 4   GA Headley        22    40         4  2190                 270  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s  Rookie_Year  \
# 0        9800                58.60   29  13  7.0  626+   6         1928
# 1        2063                63.79    5   5  NaN   137  24         2022
# 2        2667                55.68    5   4  2.0   186   5         2015
# 3        1707                54.48    7  11  1.0  246+  11         1963
# 4         416                56.00   10   5  2.0  104+   1         1930
#
#    Final_Year Country  career_length
# 0        1948     AUS             20
# ...

# %%
# Average Career Length
df["career_length"].mean()
# Out:
# np.float64(12.796875)

# %%
# Average Batting_Strike_Rate for cricketers who played over 10 years
df[df["career_length"] > 10]["Batting_Strike_Rate"].mean()
# Out:
# np.float64(47.97636363636364)

# %%
# Number of cricketers who played before 1960
df[df["Rookie_Year"] < 1960]["Player"].count()
# Out:
# np.int64(23)

# %%
# Highest Inns Score by country
df.groupby("Country")["Highest_Inns_Score"].max().sort_values(ascending=False)
# Out:
# Country
# ICC/WI     400
# AUS        380
# SL         374
# WI         365
# ENG        364
# ICC/PAK    329
# ICC/IND    319
# PAK        313
# SA         278
# ICC/SA     277
# IND        254
# NZ         251
# ZIM        232
# Name: Highest_Inns_Score, dtype: int64

# %%
# Hundreds, Fifties, ducks(0) AVG by country
df.groupby("Country")[["100", "50", "0"]].mean(numeric_only=True)
# Out:
#                100         50          0
# Country
# AUS      21.533333  29.066667   8.933333
# ENG      12.642857  20.571429   4.538462
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      24.600000  31.200000   9.600000
# NZ       33.000000  37.000000  11.000000
# PAK      17.800000  24.200000   8.000000
# SA        9.800000  20.200000   3.400000
# SL       22.750000  34.250000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
